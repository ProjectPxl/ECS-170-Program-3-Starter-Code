# %%
import numpy as np
import matplotlib.pyplot as plt

r = np.load('rewards-itr.npy')
l = np.load('losses-itr.npy')

# %%
x_val = [x[0] for x in r]
y_val = [x[1] for x in r]
plt.title('Rewards', fontsize="20")
plt.xlabel('frame id', fontsize="20")
plt.ylabel('reward', fontsize="20")
plt.plot(x_val,y_val)

# %% [markdown]
# # Raw rewards

# %%
print ([x[1] for x in r])
# Out:
# [-21.0, -19.0, -21.0, -21.0, -19.0, -20.0, -21.0, -20.0, -18.0, -17.0, -18.0, -19.0, -20.0, -21.0, -19.0, -20.0, -20.0, -17.0, -16.0, -21.0, -18.0, -14.0, -19.0, -15.0, -20.0, -19.0, -18.0, -20.0, -15.0, -18.0, -19.0, -18.0, -17.0, -19.0, -15.0, -17.0, -17.0, -15.0, -15.0, -14.0, -19.0, -17.0, -15.0, -13.0, -16.0, -16.0, -16.0, -15.0, -11.0, -18.0, -9.0, -13.0, -10.0, -18.0, -9.0, -15.0, -17.0, -15.0, -15.0, -13.0, -12.0, -14.0, -15.0, -14.0, -12.0, -12.0, -15.0, -6.0, -9.0, -12.0, -10.0, -16.0, -12.0, -11.0, -14.0, -6.0, -14.0, -12.0, -12.0, -14.0, -10.0, -14.0, -15.0, -13.0, -15.0, -7.0, -8.0, -16.0, -13.0, -13.0, -9.0, -9.0, -11.0, -12.0, -18.0, -17.0, -17.0, -17.0, -14.0, -14.0, -17.0, -11.0, -12.0, -13.0, -7.0, -16.0, -15.0, -10.0, -7.0, -8.0, -10.0, -9.0, -12.0, -8.0, -12.0, -12.0, -5.0, -12.0, -5.0, -11.0, -11.0, -12.0, -10.0, -9.0, 2.0, -8.0, -9.0, -12.0, -18.0, -8.0]

# %%
x_val = [x[0] for x in l]
y_val = [x[1] for x in l]
plt.title('Losses', fontsize="20")
plt.xlabel('frame id', fontsize="20")
plt.ylabel('loss', fontsize="20")
plt.plot(x_val,y_val)
